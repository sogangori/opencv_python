# %% [markdown]
# ## 퓨리에 변환

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
# %matplotlib inline

# %%
import matplotlib as mpl
mpl.rcParams['image.cmap'] = 'gray'

# %%
# !dir
# Out:
# A.png
# apple.jpg
# clahe_1.jpg
# dark2.jpg
# dark.jpeg
# frog.jpeg
# Image\ Processing\ -\ countour.ipynb
# Image\ Processing\ -\ FFT.ipynb
# Image\ Processing\ -\ gradient.ipynb
# Image\ Processing\ -\ Image\ Pyramids.ipynb
# Image\ Processing\ -\ morphology.ipynb
# Image\ Processing\ -\ smoothing.ipynb
# Image\ Processing\ -\ transformation.ipynb
# 영수증.jpg
# operation.ipynb
# stick.jpg

# %%
img = cv2.imread('dark2.jpg')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
plt.figure(figsize=(10,10))
plt.imshow(gray)

# %%
f = np.fft.fft2(gray)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))
magnitude_spectrum.min(), magnitude_spectrum.max()
# Out:
# (-6.664334134473933, 335.64166074324976)

# %%
plt.figure(figsize=(10,10))
plt.imshow(magnitude_spectrum, cmap='gray')

# %% [markdown]
# 퓨리에 역변환

# %%
rows, cols = gray.shape
crow,ccol = rows//2 , cols//2
scope = 30
fshift[crow-scope:crow+scope, ccol-scope:ccol+scope] = 0
f_ishift = np.fft.ifftshift(fshift)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)

# %%
plt.figure(figsize=(10,10))
plt.imshow(img_back)
