# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('pm25.png')
img.shape
# Out:
# (300, 300, 3)

# %%
plt.imshow(img)

# %%
# !pip install pytesseract
# Out:
# ...
#   Running setup.py bdist_wheel for pytesseract: started
#   Running setup.py bdist_wheel for pytesseract: finished with status 'done'
#   Stored in directory: C:\Users\sogan\AppData\Local\pip\Cache\wheels\78\c9\ac\4cb76bd547f9970070522439e5203ba7926c5c5c4f131583ea
# Successfully built pytesseract
# ...

# %%
import pytesseract

# %%
# !tesseract
# Out:
# Usage:
#   tesseract --help | --help-extra | --version
#   tesseract --list-langs
#   tesseract imagename outputbase [options...] [configfile...]
#
# OCR options:
#   -l LANG[+LANG]        Specify language(s) used for OCR.
# NOTE: These options must occur before any configfile.
#
# Single options:
#   --help                Show this help message.
#   --help-extra          Show extra help for advanced users.
#   --version             Show version information.
#   --list-langs          List available languages for tesseract engine.

# %%
txt = pytesseract.image_to_string(img, 'kor')

# %%
print(txt)
# Out:
# 초 미세 먼지 예보
#
# 1
# 머신러닝
# 시계열데이터
# 틈시띠
